# %%
pip install spotipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.8/251.8 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import numpy as np  # To calculate the median

# Spotify API setup
client_id = '1a955744b8014ad6b1e80a0d7501b081'
client_secret = '4e028e2a35af49daaf5625f532481b08'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_playlist_energy(playlist_url, max_tracks=40):
    playlist_id = playlist_url.split("/")[-1].split("?")[0]
    results = sp.playlist_tracks(playlist_id, limit=max_tracks)
    tracks = results['items']
    while results['next'] and len(tracks) < max_tracks:
        results = sp.next(results)
        tracks.extend(results['items'])

    # Ensure only max_tracks are processed
    tracks = tracks[:max_tracks]
    track_ids = [track['track']['id'] for track in tracks if track['track']]
    features = sp.audio_features(track_ids)
    energies = [feature['energy'] for feature in features if feature]
    return energies

# URLs of the playlists and their corresponding intensity labels
playlist_info = [
    ('https://open.spotify.com/playlist/37i9dQZF1EIefLxrHQP8p4?si=99f74abcbed24f60', 'Dancing'),
    ('https://open.spotify.com/playlist/37i9dQZF1EIdEHUkBXtKK5?si=4ded0f1f634d4a0a', 'Running|Cycling'),
    ('https://open.spotify.com/playlist/37i9dQZF1EIdy7dVdne3kM?si=2c4aaa06dcd8411e', 'Fighting')
]

# Plot setup
plt.figure(figsize=(10, 6))
for i, (playlist_url, intensity_label) in enumerate(playlist_info):
    try:
        energies = get_playlist_energy(playlist_url)
        median_energy = np.median(energies)
        plt.plot(energies, marker='', linestyle='-', label=f'{intensity_label} (Median: {median_energy:.2f})')
        plt.axhline(median_energy, color='grey', linestyle='--', linewidth=0.8)
    except Exception as e:
        print(f"Failed to process {intensity_label}: {str(e)}")

plt.xlabel('Tracks')
plt.ylabel('Energy')
plt.title('Energy Distribution Across High Intensity Actions')
plt.legend()
plt.show()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import numpy as np  # To calculate the median

# Spotify API setup
client_id = '1a955744b8014ad6b1e80a0d7501b081'
client_secret = '4e028e2a35af49daaf5625f532481b08'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_playlist_energy(playlist_url, max_tracks=40):
    playlist_id = playlist_url.split("/")[-1].split("?")[0]
    results = sp.playlist_tracks(playlist_id, limit=max_tracks)
    tracks = results['items']
    while results['next'] and len(tracks) < max_tracks:
        results = sp.next(results)
        tracks.extend(results['items'])

    # Ensure only max_tracks are processed
    tracks = tracks[:max_tracks]
    track_ids = [track['track']['id'] for track in tracks if track['track']]
    features = sp.audio_features(track_ids)
    energies = [feature['energy'] for feature in features if feature]
    return energies

# URLs of the playlists and their corresponding intensity labels
playlist_info = [
    ('https://open.spotify.com/playlist/37i9dQZF1EIgG2NEOhqsD7?si=01d6f550a5634e90', 'Laughing|Clapping'),
    ('https://open.spotify.com/playlist/5TDtuKDbOhrfW7C58XnriZ?si=66efc017b1df446a', 'Listening to Music')
]

# Plot setup
plt.figure(figsize=(10, 6))
for i, (playlist_url, intensity_label) in enumerate(playlist_info):
    try:
        energies = get_playlist_energy(playlist_url)
        median_energy = np.median(energies)
        plt.plot(energies, marker='', linestyle='-', label=f'{intensity_label} (Median: {median_energy:.2f})')
        plt.axhline(median_energy, color='grey', linestyle='--', linewidth=0.8)
    except Exception as e:
        print(f"Failed to process {intensity_label}: {str(e)}")

plt.xlabel('Tracks')
plt.ylabel('Energy')
plt.title('Energy Distribution Across Medium Intensity Actions')
plt.legend()
plt.show()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import numpy as np  # To calculate the median

# Spotify API setup
client_id = '1a955744b8014ad6b1e80a0d7501b081'
client_secret = '4e028e2a35af49daaf5625f532481b08'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_playlist_energy(playlist_url, max_tracks=40):
    playlist_id = playlist_url.split("/")[-1].split("?")[0]
    results = sp.playlist_tracks(playlist_id, limit=max_tracks)
    tracks = results['items']
    while results['next'] and len(tracks) < max_tracks:
        results = sp.next(results)
        tracks.extend(results['items'])

    # Ensure only max_tracks are processed
    tracks = tracks[:max_tracks]
    track_ids = [track['track']['id'] for track in tracks if track['track']]
    features = sp.audio_features(track_ids)
    energies = [feature['energy'] for feature in features if feature]
    return energies

# URLs of the playlists and their corresponding intensity labels
playlist_info = [
    ('https://open.spotify.com/playlist/37i9dQZF1DX8Uebhn9wzrS?si=b92948fd17f944ba', 'Sitting|Sleeping'),
    ('https://open.spotify.com/playlist/37i9dQZF1EIgoYQUuS02Ii?si=6d72c7b1c37a4cc2', 'Eating|Drinking'),
    ('https://open.spotify.com/playlist/37i9dQZF1EIf39kP8Wfs5X?si=9207db364e1d4917', 'Texting|Laptop|Calling')
]

# Plot setup
plt.figure(figsize=(10, 6))
for i, (playlist_url, intensity_label) in enumerate(playlist_info):
    try:
        energies = get_playlist_energy(playlist_url)
        median_energy = np.median(energies)
        plt.plot(energies, marker='', linestyle='-', label=f'{intensity_label} (Median: {median_energy:.2f})')
        plt.axhline(median_energy, color='grey', linestyle='--', linewidth=0.8)
    except Exception as e:
        print(f"Failed to process {intensity_label}: {str(e)}")

plt.xlabel('Tracks')
plt.ylabel('Energy')
plt.title('Energy Distribution Across Medium Intensity Actions')
plt.legend()
plt.show()
